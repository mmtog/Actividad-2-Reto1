# %% [markdown]
# <a href="https://colab.research.google.com/github/freddy-7/TI2001B-2023/blob/main/1_Extracci%C3%B3n_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# CARGA DE ARCHIVO .CSV

# %%
#Convertir en dataframe
df= pd.read_csv("Exportaciones.csv")
df
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1      alb  1997      otherprim        0.0521       5.7779    0.0979
# 2      alb  1997         energy       12.8071       3.0441  195.5730
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 4      alb  1997     bevtobacco        0.0022       0.0003    0.0036
# ...    ...   ...            ...           ...          ...       ...
# 13198  zwe  2011        finance       15.7700       0.3200    0.2900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13201  zwe  2011      oconsumer        3.0600       0.0700    0.0800
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
data = pd.read_csv('Exportaciones.csv')
data.head(5)
# Out:
#   iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  g_procfoods  \
# 0  alb  1997     primaryagr       93.3774       0.0143    0.2158      25.0267
# 1  alb  1997      otherprim        0.0521       5.7779    0.0979       0.1047
# 2  alb  1997         energy       12.8071       3.0441  195.5730      19.9136
# 3  alb  1997      procfoods        0.8223       0.0041    0.0706      26.5645
# 4  alb  1997     bevtobacco        0.0022       0.0003    0.0036       0.0026
#
#    g_bevtobacco  g_textiles  g_clothing  ...  h_finance  h_insurance  \
# 0        0.3817      0.1455      0.9488  ...     0.0019       0.0016
# 1        0.0016      0.0062      0.0270  ...     0.0004       0.0002
# 2        0.5700      7.7880     21.7902  ...     0.0188       0.0105
# 3        0.0075      0.0079      0.0795  ...     0.0003       0.0002
# 4        0.6704      0.0003      0.0013  ...     0.0000       0.0000
#
#    h_obsict  h_oconsumer  h_oservices  DomVAshare   GXshare   DXshare  \
# ...

# %%
filtro1 = df[(df['iso3'] == 'alb') & (df['h_insurance'] > 0.5)]
filtro1
# Out:
#      iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 1805  alb  2001      insurance        0.5881       0.1019    0.4346
# 3830  alb  2004      insurance        1.0154       0.2250    1.1321
# 3832  alb  2004      oconsumer        2.5977       0.7691    1.2608
# 6908  alb  2007      insurance        1.4055       0.5598    0.3328
# 6910  alb  2007      oconsumer        3.5501       1.8769    0.3671
# 9986  alb  2011      insurance        1.9300       0.9500    0.3700
# 9988  alb  2011      oconsumer        4.7900       3.0200    0.4100
#
#       g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 1805       0.6516        0.0306      0.1680      0.4371  ...     0.1104
# 3830       1.1834        0.0820      0.3551      0.7406  ...     0.5105
# 3832       2.9437        0.1398      1.5371      1.8077  ...     0.3095
# 6908       1.5858        0.0938      0.5638      0.9704  ...     1.5957
# ...

# %%
filtro2 = df= df[(df['sector_GMatrix'] == 'insurance') & (df['g_procfoods'] > 7)]
filtro2
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 50     arg  1997      insurance       33.6523       0.1945   18.3172
# 77     aus  1997      insurance      102.2560      13.0391    6.3998
# 104    aut  1997      insurance        1.1619       0.6656    1.0548
# 131    bel  1997      insurance        5.8961       0.8964    0.6508
# 158    bgd  1997      insurance        1.8448       2.4555    0.1200
# ...    ...   ...            ...           ...          ...       ...
# 13064  usa  2011      insurance      759.4300     101.2600  657.7600
# 13091  ven  2011      insurance       13.2100       5.2000   34.9900
# 13118  vnm  2011      insurance        2.2900       3.0200    2.1900
# 13145  zaf  2011      insurance      387.2100     294.9800  148.8600
# 13172  zmb  2011      insurance        2.1500       1.2900    0.8900
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
filtro3 = df_filtered = df[(df['year'] >= 1997) & (df['year'] <= 2005)]
filtro3
# Out:
#      iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 50    arg  1997      insurance       33.6523       0.1945   18.3172
# 77    aus  1997      insurance      102.2560      13.0391    6.3998
# 104   aut  1997      insurance        1.1619       0.6656    1.0548
# 131   bel  1997      insurance        5.8961       0.8964    0.6508
# 158   bgd  1997      insurance        1.8448       2.4555    0.1200
# ...   ...   ...            ...           ...          ...       ...
# 6611  twn  2004      insurance       12.8090       3.4212    4.2001
# 6692  ukr  2004      insurance        4.9139       3.5987   59.5590
# 6746  usa  2004      insurance      553.0360      57.9266  410.2710
# 6773  ven  2004      insurance        3.4137       1.6057   20.2249
# 6827  zaf  2004      insurance      235.5240     133.2500  132.4490
#
#       g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 50       268.6870       63.8258     65.6407     61.0232  ...     0.2530
# ...

# %%
filtro4= df[(df['VXsharefwd'] > 0.5) & (df['VXsharebwd'] < 0.5)]
filtro4
# Out:
# Empty DataFrame
# Columns: [iso3, year, sector_GMatrix, g_primaryagr, g_otherprim, g_energy, g_procfoods, g_bevtobacco, g_textiles, g_clothing, g_leather, g_lumber, g_paperpub, g_chemicals, g_nonmetmin, g_metals, g_fabmetals, g_transpequip, g_machinery, g_othermanuf, g_water, g_construction, g_distribution, g_transport, g_communcation, g_finance, g_insurance, g_obsict, g_oconsumer, g_oservices, sector_HMatrix, h_primaryagr, h_otherprim, h_energy, h_procfoods, h_bevtobacco, h_textiles, h_clothing, h_leather, h_lumber, h_paperpub, h_chemicals, h_nonmetmin, h_metals, h_fabmetals, h_transpequip, h_machinery, h_othermanuf, h_water, h_construction, h_distribution, h_transport, h_communcation, h_finance, h_insurance, h_obsict, h_oconsumer, h_oservices, DomVAshare, GXshare, DXshare, VXsharefwd, VXsharebwd]
# Index: []
#
# [0 rows x 63 columns]

# %%
filtro5 = df[(df['iso3'].isin(['tha', 'kor', 'phl', 'ven', 'deu'])) &
                 (df['g_textiles'] > 1) &
                 (df['g_clothing'] < 1)]

# %%
filtro52 = filtro5.head(100)
filtro52
# Out:
# Empty DataFrame
# Columns: [iso3, year, sector_GMatrix, g_primaryagr, g_otherprim, g_energy, g_procfoods, g_bevtobacco, g_textiles, g_clothing, g_leather, g_lumber, g_paperpub, g_chemicals, g_nonmetmin, g_metals, g_fabmetals, g_transpequip, g_machinery, g_othermanuf, g_water, g_construction, g_distribution, g_transport, g_communcation, g_finance, g_insurance, g_obsict, g_oconsumer, g_oservices, sector_HMatrix, h_primaryagr, h_otherprim, h_energy, h_procfoods, h_bevtobacco, h_textiles, h_clothing, h_leather, h_lumber, h_paperpub, h_chemicals, h_nonmetmin, h_metals, h_fabmetals, h_transpequip, h_machinery, h_othermanuf, h_water, h_construction, h_distribution, h_transport, h_communcation, h_finance, h_insurance, h_obsict, h_oconsumer, h_oservices, DomVAshare, GXshare, DXshare, VXsharefwd, VXsharebwd]
# Index: []
#
# [0 rows x 63 columns]

# %%
filtro1.to_csv("f1.csv")

# %%
filtro2.to_csv("f2.csv")

# %%
filtro3.to_csv("f3.csv")

# %%
filtro4.to_csv("f4.csv")

# %%
filtro52.to_csv("f52.csv")
